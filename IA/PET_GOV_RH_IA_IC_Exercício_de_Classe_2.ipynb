# %% [markdown]
# <a href="https://colab.research.google.com/github/mhlfsb/PET-GOV/blob/main/IA/PET_GOV_RH_IA_IC_Exerc%C3%ADcio_de_Classe_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![banner.png](data:image/png;base64,...)

# %% [markdown]
# # **Inteligência Artificial, Ciência de dados e Analytics**
#
# Programa de formação de RH-Público em Inteligência Artificial, Ciência de Dados e Analytics (RH.IA-PE)
#
# **Professor Responsável Projeto:** Ph.D. Fernando Buarque de Lima Neto
#
# **Professor do módulo**: Ph.D. Fernando Buarque de Lima Neto
#
# Mestrando Gabriel Kopte
#
#
# ---
#
#
# **Módulo:** 2 - Inteligência Artificial
#
# **Atividade:** Aula 05 - *Agrupadores* K-means e Self Organazing Maps (SOM)

# %% [markdown]
# #**Exercício de Classe-2: *Agrupadores* K-means e Self Organazing Maps (SOM)**

# %% [markdown]
# # **K-mean**

# %% [markdown]
# ## 1. O que K-Means faz?
#
# Agrupamento K-means (K-means clustering) é um tipo de aprendizado não supervisionado utilizado quando temos dados não rotulados (por exemplo, dados sem grupos ou categorias definidas). O objetivo deste algoritmo é encontrar grupos no conjunto de dados, sendo o número de grupos formado representado pela variável K. O algoritmo trabalha iterativamente para atribuir cada um dos dados a um dos K grupos com base nas características fornecidas.  Os dados são agrupados por similaridade. Os resultados gerados pelo algoritmo Agrupamento K-means (K-means clustering) são:
#
# * Os centroides dos K clusters (agrupamentos), que podem ser usados para rotular novos dados
# * Rótulos para os dados de treinamento (cada um dos dados é atribuído a um único cluster)

# %% [markdown]
# ## 2. Aplicações </br>
# O algoritmo Agrupamento K-means (K-means clustering) é usado para encontrar grupos que não tenham sido explicitamente rotulados no conjunto de dados. Pode ser usado para confirmar suposições sobre que tipos de grupos existem ou identificar grupos desconhecidos em conjuntos de dados complexos.  Uma vez que o algoritmo tenha sido executado e os grupos definidos, qualquer novo dado pode ser facilmente atribuído ao grupo correto.
#
# É um algoritmo versátil que pode ser usado para qualquer tipo de agrupamento. Alguns exemplos de casos de uso são:
#
# * Segmentação comportamental:
# ** Segmento por histórico de compras
# ** Segmento por atividades em aplicativo, website ou plataforma
# * * Definição de perfils baseados em interesses
# * * Criação de perfis com base em monitoração de atividade
# * Categorização de Inventário:
# * * Inventário de grupo por atividade de vendas
# * * Inventário de grupo por métricas de fabricação
# * Classificação de medidas de sensores:
# * * Detecção de tipos de atividade em sensores de movimento
# * * Agrupar imagens
# * * Separar áudio
# * * Identificar grupos no monitoramento de saúde
# * Detectar robôs ou anomalias:
# * * Separar grupos de atividades válidos de robôs
#
# <a id="3"></a>

# %% [markdown]
# ## 3. Funcionamento
#
# Vamos discutir agora o funcionamento do algoritmo K-Means  O objetivo é explicar da forma mais simples possível.

# %% [markdown]
# ### **Passo 1** </br>
# #### **Escolher o número de clusters (K)**

# %% [markdown]
# #### Começamos escolhendo o número de grupos K. O K significa o número de grupos que o algoritmo deve encontrar no conjunto de dados. A escolha do K correto é muito importante. Algumas vezes o K é claramente visível a partir da visualização do conjunto de dados. No entanto, na maior parte das vezes não é esse o caso, veremos em breve como escolher o valor correto de K.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Passo 2** </br>
# #### **Inicialização aleatória dos centróides**

# %% [markdown]
# #### O segundo passo é atribuir pontos K aleatórios como centroides. Esses pontos K podem ser do conjunto de dados ou externos. Porém, há uma coisa a se levar em consideração. A inicialização aleatória dos centroides pode ocasionar armadilhas de inicialização aleatória como veremos mais adiante.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Passo 3** </br>
# #### **Associa cada dado a cluster mais próximo**

# %% [markdown]
# #### No terceiro passo cada um dos dados do conjunto será atribuído ao centroide mais próximo.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Passo 4** </br>
# #### **Cálcula novos centróides**

# %% [markdown]
# #### O quarto passo é calcular o centroide de cada agrupamento e posicionar o antigo centroide lá.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Passo 5** </br>
# #### **reassocia cada dado aos novos centróides mais próximos**

# %% [markdown]
# #### O quinto passo é realocar os dados como feito no passo 3. Se houver realocação é necessário repetir o passo 4. Se não houver realocação podemos dizer que o modelo convergiu e está pronto.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.1 Armadilhas da Inicialização Aleatória dos Centroides

# %% [markdown]
# Observando as imagens vamos ver como duas inicializações aleatórias podem gerar resultados completamente diferentes.
#
# #### Inicialização 1
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Inicialização 2
#
# ![image.png](data:image/png;base64,...)
#
#
# Então vimos que mesmo com uma clara distinção visualmente possível, a randomização errada pode produzir resultados errados.

# %% [markdown]
# **Inicialização com K-mean++**
#
#
# O algoritmo K-mean++ garante uma inicialização mais inteligente dos centroides e melhora a qualidade do agrupamento. Além da inicialização, o resto do algoritmo é igual ao K-means padrão.
#
# Algoritmo de inicialização:
#
#
# 1.   Selecione aleatoriamente o primeiro centroide entre os dados existentes.
# 2.   Para cada dado (observação), calcule sua distância do centróide mais próximo, previamente escolhido.
# 3.   Selecione o próximo centróide entre as observações (dados) de forma que a probabilidade de escolher uma observação como centróide seja diretamente proporcional à sua distância do centróide mais próximo. Ou seja, observação com distância máxima do centróide mais próximo provavelmente será selecionado como centróide.
# 4.   Repita os passos 2 e 3 até que k centroides tenham sido amostrados

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Escolhendo o K correto

# %% [markdown]
# Uma forma de escolher o K correto é utilizando-se de um parâmetro conhecido como WCSS que é a sigla para Soma dos Quadrados Dentro de um Grupo (**Within Cluster Sum of Squares**). Aqui está a fórmula para quando o K=3
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Quanto menor o WCSS, mais próximo cada observação está do seu respectivo centróide. Em outras palavras, quanto menor WCSS, mais homogêneo é cada cada cluster.

# %% [markdown]
# ### Elbow Method

# %% [markdown]
# O Método do Cotovelo (Elbow Method) pode ser utilizado para escolher o melhor valor de K. **O método consiste em plotar o WCSS em função do número de clusters**. O gráfico tem um formato de cotovelo e **geralmente** é uma boa ideia escolher o número onde esse cotovelo se forma. </br>**Obs.: Na pratica haverá muitos casos em que o gráfico não será tão intuitivo.**
#
#
# ![image.png](data:image/png;base64,...)
#
# <a id="5"></a>

# %% [markdown]
# ## 6. Implementação
#
#
#
#
# <a id="7"></a>

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive')

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context="notebook", palette="Spectral", style = 'darkgrid' ,font_scale = 1.5, color_codes=True)

# %% [markdown]
# **Base de dados: Clientes de Um Shopping Center**
#
# Esta base de dados conta com informações de clientes de um shopping center. O shopping estabeleceu uma pontuação para cada cliente baseado em seu histórico de compras.

# %%
# Importando o conjunto de dados usando pandas
dataset = pd.read_csv('/content/drive/Shared drives/Módulo 2 - PET-GOV-RH-IA - Inteligência Artificial/Data/Mall_Customers.csv',index_col='CustomerID')

# %% [markdown]
# Vamos imprimir informações básicas do nosso dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Genre               200 non-null    object
#  1   Age                 200 non-null    int64
#  2   Annual_Income_(k$)  200 non-null    int64
#  3   Spending_Score      200 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 7.8+ KB

# %% [markdown]
# Descrição das colunas:
#
# 1.  Gênero
# 2.  Idade
# 3.  Renda Anual em milhares de dólares
# 4.  Pontução (quando maior, mais o cliente gasta neste shopping)

# %% [markdown]
# Podemos também imprimir estatisticas básicas das colunas do dataset da seguinte maneira:

# %%
dataset.describe()
# Out:
#               Age  Annual_Income_(k$)  Spending_Score
# count  200.000000          200.000000      200.000000
# mean    38.850000           60.560000       50.200000
# std     13.969007           26.264721       25.823522
# min     18.000000           15.000000        1.000000
# 25%     28.750000           41.500000       34.750000
# 50%     36.000000           61.500000       50.000000
# 75%     49.000000           78.000000       73.000000
# max     70.000000          137.000000       99.000000

# %%
dataset.head(10)
# Out:
#              Genre  Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 1             Male   19                  15              39
# 2             Male   21                  15              81
# 3           Female   20                  16               6
# 4           Female   23                  16              77
# 5           Female   31                  17              40
# 6           Female   22                  17              76
# 7           Female   35                  18               6
# 8           Female   23                  18              94
# 9             Male   64                  19               3
# 10          Female   30                  19              72

# %% [markdown]
# Checamos se o dataset esta completo ou possui algum NaN (Not a Number). </br>
# **NaN é o valor retornado quando o resultado de um cálculo não pode ser expresso como um número. </br> Obs.: Qualquer operação matemática com NaN também vai resultar em um NaN** </br>
#
# Checamos se existe NaN no dataset da eguinte maneira:

# %%
dataset.isnull().sum()
# Out:
# Genre                 0
# Age                   0
# Annual_Income_(k$)    0
# Spending_Score        0
# dtype: int64

# %% [markdown]
# **Nenhum NaN (Not a Number) encontrado!**

# %% [markdown]
# Neste caso, não existe NaN no dataset. Porém vamos adicionar um NaN propositalmnete para mostrarmos uma das formas de contornar este problema.

# %%
from math import nan
dataset['Age'].loc[1] = nan
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
dataset.head(3)
# Out:
#              Genre   Age  Annual_Income_(k$)  Spending_Score
# CustomerID
# 1             Male   NaN                  15              39
# 2             Male  21.0                  15              81
# 3           Female  20.0                  16               6

# %%
dataset.isnull().sum()
# Out:
# Genre                 0
# Age                   1
# Annual_Income_(k$)    0
# Spending_Score        0
# dtype: int64

# %% [markdown]
# Uma das formas de lidar com valores que estão faltando no dataset (neste caso NaN) é substituir os NaNs pelos valor médio da respectiva coluna. </br>
# Podemos fazer da seguinte maneira no pandas

# %%
dataset['Age'].fillna(dataset['Age'].mean(),inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Genre                 0
# Age                   0
# Annual_Income_(k$)    0
# Spending_Score        0
# dtype: int64

# %%
dataset.describe()
# Out:
#               Age  Annual_Income_(k$)  Spending_Score
# count  200.000000          200.000000      200.000000
# mean    38.949749           60.560000       50.200000
# std     13.897597           26.264721       25.823522
# min     18.000000           15.000000        1.000000
# 25%     29.000000           41.500000       34.750000
# 50%     36.000000           61.500000       50.000000
# 75%     49.000000           78.000000       73.000000
# max     70.000000          137.000000       99.000000

# %%
# removendo os dados duplicados
dataset.drop_duplicates(inplace=True)

# %% [markdown]
# Para facilitar a vizualização e interpretação, neste exemplo, vamos utilizar apenas as colunas *Spending_Score* e *Annual_Income_(k$)*

# %%
# utilizando apenas Spending_Score e vriáveis de entrada para facilitar a visualização
# X = dataset.iloc[:, [2, 3]].values
X = dataset[['Annual_Income_(k$)', 'Spending_Score']].values

# %%
print('Tipo:', type(X))
print('Shape: ',X.shape)
# Out:
# Tipo: <class 'numpy.ndarray'>
# Shape:  (200, 2)

# %% [markdown]
# Vamos vizualizar o gráfico antes da clusterização.

# %%
annual_income = X[:,0]
spending_score = X[:,1]

fig = plt.figure(figsize=(6,6))
plt.scatter(annual_income, spending_score)
plt.suptitle("Gráfico de dispersão: Renda Anual (k$) VS Pontuação do Cliente (1-100)")
plt.xlabel("Renda Anual (k$)")
plt.ylabel("Pontuação do Cliente (1-100)")
plt.show()

# %% [markdown]
# ### Elbow Method

# %% [markdown]
# Vamos utilizar o K-means da biblioteca Scikit-learn (sklearn) </br>
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
# Utilizando o método do cotovelo para encontrar o número ideal de grupos
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42) #Utilizamos o método de inicialização k-mean++
    kmeans.fit(X)
    # inertia method returns wcss for that model
    wcss.append(kmeans.inertia_)

# %%
plt.figure(figsize=(10,5))
sns.lineplot(range(1, 11), wcss,marker='o',color='red')
plt.title('Elbow Method')
plt.xlabel('Número de Grupos')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# De acordo com o método do cotovelo devemos escolher K = 5! </br>
# Portanto, vamos treinar nosso modelo com o parametro `n_clusters = 5`

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %% [markdown]
# ## 7. Visualização

# %%
# Visualizando os grupos
plt.figure(figsize=(15,7))
sns.scatterplot(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], color = 'yellow', label = 'Cluster 1',s=50)
sns.scatterplot(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], color = 'blue', label = 'Cluster 2',s=50)
sns.scatterplot(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], color = 'green', label = 'Cluster 3',s=50)
sns.scatterplot(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], color = 'grey', label = 'Cluster 4',s=50)
sns.scatterplot(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], color = 'orange', label = 'Cluster 5',s=50)
sns.scatterplot(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color = 'red', 
                label = 'Centroids',s=300,marker=',')
plt.grid(False)
plt.title('Grupos de Clientes')
plt.xlabel('Renda Anual (k$)')
plt.ylabel('Pontuação do Cliente (1-100)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# #### Análise do resultado

# %% [markdown]
# Podemos perceber 5 grupos de clientes do shopping:
#
# **Cluster 1** : renda mediana e compradores moderados
#
# **Cluster 2** : renda alta e compradores esporádicos
#
# **Cluster 3** : renda baixa e compradores esporádicos
#
# **Cluster 4**: renda baixa e compradores frequentes
#
# **Cluster 5** : renda alta e compradores frequentes

# %% [markdown]
# Referencias:
#
# * https://www.datascience.com/blog/k-means-clustering
# * https://www.superdatascience.com
# * http://ilpubs.stanford.edu:8090/778/1/2006-13.pdf

# %% [markdown]
# # **Self Organazing Maps (SOM) para detecção de anomalías**

# %%
# %%capture
# !pip install MiniSom

# %% [markdown]
# Referência: https://sklearn-som.readthedocs.io/en/latest/index.html

# %%
# IPython magic comentada para garantir a compatibilidade do Python. 
from IPython. display import Image

from minisom import MiniSom
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns
from matplotlib import colors
import random
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import pandas as pd

# %matplotlib inline
# %load_ext autoreload

# Manutenção Preditiva sem rótulos: Mapas auto-organizados para detecção de anomalias

# %% [markdown]
# ## Background
#
# Existem alguns métodos para detectar anomalias.  É possível utilizar modelos de aprendizado de máquina supervisionados e não supervisionados. **A vantagem de utilizar modelos não supervisionados só são necessários dados do estado atual da máquina**. Para métodos supervisionados são necessários dados do estado atual e de falhas anteriores. No entanto dados do sensor de falha da máquina são raros e caros, então começar com modelos não supervisionados normalmente é mais barato e mais rápido.
#
# SOM é um método de machine learning frequentemente utilizado produzir uma representação em poucas dimesões de dados com alta dimensionalidade. preservando a topologia da estrutura dos dados. O SOM é uma Articial Neural Network (ANN) treinada utilizando aprendizado competitivo ao invés de métodos baseados em gradiente utilizados por outros tipos de ANN. Também são chamadas de *Kohonen map* ou *Kohonen network*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##### Referências

# %% [markdown]
# 1. https://sci2s.ugr.es/keel/pdf/algorithm/articulo/1990-Kohonen-PIEEE.pdf </br>
# 2. https://stackabuse.com/self-organizing-maps-theory-and-implementation-in-python-with-numpy/

# %% [markdown]
# ## Treinamento
#
# 1. Inicializar pesos aleatoriamente </br>
# **Repetir por N iterações**
# 2. Selecionar um dado aleatório no conjunto de treinamento
# 3. Calcular a Melhor Unidade de Correspondência (Best Matching Unit - BMU)
# 4. Calcular a vizinhança da BMU
# 5. Ajustar os pesos

# %% [markdown]
# ## Agrupamento por cor
#  Este projeto demostra como SOMs podem ser utilizados para detectar anomalias usando agrupamento por cores e detectando os pontos discrepantes

# %% [markdown]
# ##### Código auxiliar

# %%
def draw_som():
    fig, ax = plt.subplots(figsize=(6, 6))
    w = som.get_weights().T
    w = np.moveaxis(w, 0, -1)
    ax.imshow(w / 256, origin="lower")
    plt.grid(False)
    
def draw_data(data):
    fig, ax = plt.subplots(figsize=(25, 20))
    ax.imshow([x / 256 for x in np.reshape([data], (-1, len(data), 3))], origin="lower")
    plt.axis('off')
    
def draw_datapoint(datapoint):
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.imshow([x / 256 for x in np.reshape([datapoint], (-1, len(datapoint), 3))], origin="lower")
    plt.axis('off')

def draw_bmu_compare(datapoint, winner_coords):
    fig, axes = plt.subplots(1, 2, figsize=(15, 7))
    axes[0].imshow([x / 256 for x in np.reshape([datapoint], (-1, len(datapoint), 3))], origin="lower")
    axes[0].axis('off')
    w = som.get_weights().T
    w = np.moveaxis(w, 0, -1)
    axes[1].imshow(w / 256, origin="lower")
    plt.plot(winner_coords[0], winner_coords[1], 'x', markeredgecolor="black", markersize=12, markeredgewidth=2)

def draw_updated_som():
    fig, axes = plt.subplots(1, 2, figsize=(15, 7))
    w = som.get_weights().T
    w = np.moveaxis(w, 0, -1)
    axes[0].imshow(w / 256, origin="lower")
    axes[0].plot(winner_coords[0], winner_coords[1], 'x', markeredgecolor="black", markersize=12, markeredgewidth=2)
    
    som.update(random_data_point, winner_coords, 0, 1)
    w = som.get_weights().T
    w = np.moveaxis(w, 0, -1)
    axes[1].imshow(w / 256, origin="lower")
    axes[1].plot(winner_coords[0], winner_coords[1], 'x', markeredgecolor="black", markersize=12, markeredgewidth=2)
    
    axes[0].grid(False)
    axes[1].grid(False)

def draw_som_and_distance_map():
    fig, axes = plt.subplots(1, 2, figsize=(15, 7))
    axes[0].imshow([x / 256 for x in som.get_weights()], origin="lower")
    axes[1].pcolor(som.distance_map().T, cmap='bone_r')
    axes[0].grid(False)
    axes[0].set_xticks([])
    axes[0].set_yticks([])

def plot_quant_errors():
    sns.set(rc={'figure.figsize':(12, 6)})
    quant_errors = [som.quantization_error([datapoint_test]) for datapoint_test in train_data]
    quant_errors_compl = pd.DataFrame({"observation": range(len(quant_errors)), "Quantization Error": quant_errors})
    # print(quant_errors_compl)
    sns.lineplot('observation', 'Quantization Error', data=quant_errors_compl, label="Train Data")

def draw_quant_errors():
    quant_errors_test = [som.quantization_error([datapoint_test]) for datapoint_test in test_data]
    test_data_df["quant_error"] = quant_errors_test

    sns.set(rc={'figure.figsize':(12, 6)})
    palette = ['#%02x%02x%02x' % (rgb[0], rgb[1], rgb[2]) for rgb in test_data_df["rgb"].to_list()]
    ax = sns.scatterplot(x=range(11), y=test_data_df["quant_error"], palette=palette,
                         hue=test_data_df["label"], legend=False, s=100, edgecolor='black')
    ax.set_xticks(range(11))
    ax.set_xticklabels(test_data_df['label'])
    plt.axhline(threshold, color='r')

# %% [markdown]
# ### Conjuntos de treino e teste

# %% [markdown]
# #### Treino

# %%
train_data = [
    [254,215,215], [254,178,178], [252,129,129], [229, 62, 62], [197, 48, 48], [155, 44, 44], [116,42,42], # red
    [254,235,200], [251,211,141], [246,173,85], [221,107,32], [192,86,33], [221,107,32], [123,52,30], #orange
    [254,252,191], [250,240,137], [246,224,94], [214,158,46], [183,121,31], [151,90,22], [116,66,16], # yellow
    [198,246,213], [154,230,180], [104,211,145], [56,161,105], [47,133,90], [39,103,73], [34,84,61], # green
    [178,245,234], [129,230,217], [79,209,197], [49,151,149], [44,122,123], [40,94,97], [35,78,82], #teal
    [190,227,248], [144,205,244], [99,179,237], [49,130,206], [43,108,176], [44,82,130], [42,67,101], # blue
    [195,218,254], [163,191,250], [127,156,245], [90,103,216], [76,81,191], [67,65,144], [60,54,107], #indigo
    [233,216,253], [214,188,250], [183,148,244], [128,90,213], [107,70,193], [85,60,154], [68,51,122], #purple
    [254,215,226], [251,182,206], [246,135,179], [213,63,140], [184,50,128], [151,38,109], [112,36,89]  # pink
]
print(len(train_data))
draw_data(train_data)
# Out:
# 63

# %% [markdown]
# #### Teste

# %%
test_data = [
    [245,101,101], #red
    [237,137,54], #orange
    [236,201,75], #yellow
    [72,187,120], #green
    [56,178,172], #teal
    [66,153,225], #blue
    [102,126,234], #indigo
    [159,122,234], #purple
    [237,100,166], #pink
    [0, 0, 0],
    [255, 255, 255]
]

test_data_df = pd.DataFrame({"label": ["red", "orange", "yellow", "green", 
                                     "teal", "blue", "indigo", "purple", 
                                     "pink", "black", "white"],
                             "rgb": test_data,
                             "quant_error": np.zeros(len(test_data))})

draw_data(test_data)

# %% [markdown]
# *Essas cores são os dados básicos de treinamento que o SOM deve agrupar*

# %% [markdown]
# ## Passo 0: Iniciar pesos

# %%
# Cria objeto SOM superfície 10x10 e 3 features. Sigma é o raio de influência em relação ao BMU
som = MiniSom(10, 10, 3,learning_rate=1, sigma=2)
# som.random_weights_init(data=train_data) # dado de treinamento escolhidos aleatóriamente
rand = np.random.RandomState(1)
som.random_weights_init(data=rand.randint(0, 255, (10, 3)))# Usa dados de treinamento aleatórios

weight_init = som.get_weights().T
print('Tipo: '+str(type(weight_init)))
print('Dim: '+str((weight_init.ndim)))
print('Shape: '+str((weight_init.shape)))
print('Pesos iniciados aleatóriamente: \n'+str(weight_init))
draw_som()
# Out:
# Tipo: <class 'numpy.ndarray'>
# Dim: 3
# Shape: (3, 10, 10)
# Pesos iniciados aleatóriamente:
# [[[252.  37. 133. 144. 133. 252.  71. 146.  71. 146.]
#   [157. 144. 252.  20. 134. 133. 157. 144. 144.  72.]
#   [157.  20. 133. 157. 134. 157. 252. 144.  71. 157.]
#   [252.  20.  37.  72. 144. 133.  37. 144.  20.  37.]
#   [ 71. 157.  37.  72.  20. 133.  20. 146.  20. 157.]
#   [ 71. 157. 134. 144.  37. 144. 134. 157. 157. 134.]
#   [157.  20.  72.  37. 134.  20. 133.  37. 252. 134.]
#   [144.  37.  37. 144. 134. 134. 252.  72. 133. 134.]
#   [146.  37. 157. 146. 134.  72. 144. 157.  72. 144.]
#   [252. 133. 134. 252.  20. 144.  37.  20. 157.  20.]]
#
#  [[234. 235.  79. 129.  79. 234. 237. 212. 237. 212.]
#   [142. 129. 234. 254.  25.  79. 142. 129. 129. 137.]
#   [142. 254.  79. 142.  25. 142. 234. 129. 237. 142.]
#   [234. 254. 235. 137. 129.  79. 235. 129. 254. 235.]
#   [237. 142. 235. 137. 254.  79. 254. 212. 254. 142.]
#   [237. 142.  25. 129. 235. 129.  25. 142. 142.  25.]
# ...

# %% [markdown]
# *Notação: Cada quadrado é um neurônio, a cor indica um vetor peso*

# %% [markdown]
# ## Passo 1: Selecionar um dado aleatório no conjunto de treinamento

# %%
random_data_point = random.choice(train_data)
draw_datapoint([random_data_point])
random_data_point
# Out:
# [40, 94, 97]

# %% [markdown]
# ## Passo 2: Encontrar a Melhor Unidade de Correspondência (Best Matching Unit - BMU)

# %% [markdown]
# _BMU_ é o neurônio cujo vetor peso tem maior similaridade com o vetor de entrada no processo de treinamento do SOM

# %% [markdown]
# Erro de Quantização:
# $ dist = \sqrt{\sum_{i=0}^{n}(V_i - W_i)^2} $ (Distância euclidiana)
#
# O BMU é o neurônio com $dist$ mínimo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
winner_coords = som.winner(random_data_point)
draw_bmu_compare([random_data_point], winner_coords)

print('Data point aleatório: '+str(random_data_point))
print('BMU: '+str(som.get_weights()[winner_coords[0]][winner_coords[1]]))
print('Coordenadas BMU: '+ str(winner_coords) )
# Out:
# Data point aleatório: [40, 94, 97]
# BMU: [ 72. 137. 203.]
# Coordenadas BMU: (2, 6)

# %% [markdown]
# ## Passo 3: Calcular a vizinhança da BMU
#
# #### Cálculo da vizinhança

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Raio diminui ao longo do treinamento. O fator de atualização máximo acontece no BMU e a influência vai diminuindo a medida que se distancia.

# %% [markdown]
# ## Passo 4: Ajustar os pesos

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Vizualizando decaimentos de $\eta^{(t)}$ e $f_{i,f}(g,h,\sigma_t)$

# %% [markdown]
# ### $\eta^{(t)}$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### $f_{i,f}(g,h,\sigma_t)$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
draw_updated_som()

# %% [markdown]
# Os passos 1 - 4 são agora repetidos por *N* iterações

# %% [markdown]
# Mapa de distância mostra a soma da distância para os neurônios adjacentes

# %%
num_iter = 100000 
sigma_vec = [0.001,0.1,1,2,5]
lr_vec = [0.001,0.1,0.5,1]
fig, axes = plt.subplots(len(lr_vec), len(sigma_vec), figsize=(20, 18))
rand = np.random.RandomState(1)

for i,sig in enumerate(sigma_vec):
  for j,lr in enumerate(lr_vec):
    som = MiniSom(10, 10, 3, learning_rate=lr, sigma=sig) # learning_rate e sigma  / som = MiniSom(10, 10, 3, learning_rate=0.001, sigma=1.2) 
    # som.random_weights_init(data=train_data)
    som.random_weights_init(data=rand.randint(0, 255, (10, 3)))

    som.train_batch(train_data, num_iter)
    
    # Plot SOM para varias combinações de Learning Rate e Raio(Sigma)
    axes[j,i].imshow([x / 256 for x in som.get_weights()], origin="lower")
    axes[j,i].grid(False)
    axes[j,i].set_xticks([])
    axes[j,i].set_yticks([])
    axes[j,i].set_title('Leaning Rate: {}\nSigma:{}'.format(lr,sig))

# %% [markdown]
# ## Resultados após o treinamento

# %% [markdown]
# ## Métricas
#
# * Erro de Quantização: É a distância média entre uma observação e o nó que melhor a representa (Best Matching Unit). É utilizado como métrica básica para avaliar SOM.
# * Erro Topográfico: É a medida de quão bem a estrutura do espaço de entrada é modelada pelo mapa. Esta medida avalia especificamente a discontinuidades no mapa. É calculada utilizando a distância do BMU (Best Matching Unit) e o Second Best Unit. Se estas duas unidades estiverem perto significa que a topologia foi preservada.
#
# *As características de qualidade podem ser checadas usando os dados de treinamento*
#
# Referência: https://homepage.cs.uri.edu/faculty/hamel/pubs/theses/ms-thesis-breard.pdf

# %%
# Cria objeto SOM superfície 10x10 e 3 features. Sigma é o raio de influência em relação ao BMU
som = MiniSom(10, 10, 3, learning_rate=0.2, sigma=1.2) # learning_rate e sigma  / som = MiniSom(10, 10, 3, learning_rate=0.001, sigma=1.2) 
# som.random_weights_init(data=train_data)
rand = np.random.RandomState(1)
#Inicializa mapa com pesos aleatórios
som.random_weights_init(data=rand.randint(0, 255, (10, 3)))

max_iter = 100000  #Define máximo número de iteração
q_error = []
t_error = []

#Roda  treinamento da SOM passo-a-passo para plotar erro de quantização e topografia em cada etapa
for i in range(max_iter):
    rand_i = np.random.randint(len(train_data))
    som.update(train_data[rand_i], som.winner(train_data[rand_i]), i, max_iter)
    q_error.append(som.quantization_error(train_data))
    t_error.append(som.topographic_error(train_data))

plt.plot(np.arange(max_iter), q_error, label='Erro de Quantização')
plt.plot(np.arange(max_iter), t_error, label='Erro Topográfico')
plt.ylabel('Erro de Quantização')
plt.xlabel('Número de Iterações')
plt.legend()
plt.show()

# %%
plot_quant_errors()
print("Erro Topográfico: %s" % som.topographic_error(train_data))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Erro Topográfico: 0.0

# %% [markdown]
# ## Utilização para Detecção de Anomalias
#
# Os agrupamentos são formados com os estados normais da máquina/processo. Para novos dados, a distância entre o dado e a BMU é examinada. **Se a distância for maior que um determinado limite, este dado é marcado como uma anomalia** (agrupamento = estado normal; grande distância do estado normal = anomalia)

# %% [markdown]
# ### Detectando anomalias no exemplo das cores

# %%
som = MiniSom(10, 10, 3, learning_rate=0.01, sigma=3.2) # learning_rate e Raio 
# som.random_weights_init(data=train_data)
rand = np.random.RandomState(1)
som.random_weights_init(data=rand.randint(0, 255, (10, 3)))

som.train_batch(train_data, num_iter)
draw_som_and_distance_map()

# %%
quant_errors = [som.quantization_error([datapoint]) for datapoint in train_data] # Cálcula os erros de quantização para todo daset de treino
threshold = 0.95 * np.amax(quant_errors) # Limiar escolhido "manualmente"

sns.distplot(quant_errors, axlabel='Erro de Quantização')
plt.axvline(threshold, color='red')
print("O limiar é %s" % threshold)

test_data = [
    [245,101,101], #red
    [237,137,54], #orange
    [236,201,75], #yellow
    [72,187,120], #green
    [56,178,172], #teal
    [66,153,225], #blue
    [102,126,234], #indigo
    [159,122,234], #purple
    [237,100,166], #pink
    [0, 0, 0], #black -> anomaly
    [255, 255, 255] #white -> anomaly
]
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# O limiar é 35.455337461125076

# %% [markdown]
# As primeiras cores devem estar próximas o suficiente dos dados de treinamento para que não sejam consideradas anomalias.  Preto e branco são tão diferentes que deveriam ser reconhecidos como anomalias.

# %%
# Plota o erro de quantização para o dataset de teste
draw_quant_errors()

#Testa Preto
random_test_data = [0, 0, 0]
winner_coords = som.winner(random_test_data)
draw_bmu_compare([random_test_data], winner_coords)
print("Erro de Quantização: %s | Limiar: %s" % (som.quantization_error([random_test_data]), threshold))
# Out:
# Erro de Quantização: 129.37490516743972 | Limiar: 35.455337461125076

# %% [markdown]
# ## Classificação de novos dados

# %%
# Você pode testar o SOM com quaisquer cores aleatórias
random_test_data=rand.randint(0, 255, 3)
# random_test_data = [25, 56, 29]
erro = som.quantization_error([random_test_data])
print('Novo dado: {}\nErro de quantização: {}'.format(random_test_data,erro))
print('Anomalia SIM') if erro > threshold else  print('Anomalia NÃO')

winner_coords = som.winner(random_test_data)
draw_bmu_compare([random_test_data], winner_coords)
# Out:
# Novo dado: [ 68 215 215]
# Erro de quantização: 37.252437910393894
# Anomalia SIM
